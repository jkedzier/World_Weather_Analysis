# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import gmaps.datasets
from datetime import datetime

# Import the API key.
from config import g_key

# Import the random module.
import random 

# Import the NumPy module.
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
#Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
#Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
            pass
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
            pass
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "description": city_weather_desc,
                          "Rain Inches (last 3 hrs)": city_rain,
                          "Snow Inches (last 3 hrs)": city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | grindavik
# Processing Record 3 of Set 1 | shimoda
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | sonqar
# City not found. Skipping...
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | juruti
# Processing Record 11 of Set 1 | kaitangata
# Processing Record 12 of Set 1 | kavieng
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | jashpurnagar
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | vila franca do campo
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | galveston
# Processing Record 20 of Set 1 | carnot
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | maldonado
# Processing Record 24 of Set 1 | hamilton
# Processing Record 25 of Set 1 | srednekolymsk
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | egvekinot
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | anori
# Processing Record 31 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | khonsar
# City not found. Skipping...
# Processing Record 34 of Set 1 | sinnamary
# Processing Record 35 of Set 1 | ahuimanu
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | north platte
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 1 | rio gallegos
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | nichinan
# Processing Record 44 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | elmina
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | ocos
# Processing Record 49 of Set 1 | belmonte
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | realeza
# Processing Record 2 of Set 2 | moura
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 2 | berlevag
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | terrace
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | kultayevo
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | poiana marului
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | inirida
# Processing Record 18 of Set 2 | vestmannaeyjar
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | soria
# Processing Record 21 of Set 2 | faanui
# Processing Record 22 of Set 2 | nalut
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | rio grande
# Processing Record 25 of Set 2 | dogondoutchi
# Processing Record 26 of Set 2 | husavik
# Processing Record 27 of Set 2 | golden
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | geraldton
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | borodino
# Processing Record 32 of Set 2 | komsomolskiy
# Processing Record 33 of Set 2 | puerto del rosario
# Processing Record 34 of Set 2 | kruisfontein
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | tosya
# Processing Record 37 of Set 2 | isangel
# Processing Record 38 of Set 2 | teahupoo
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | tual
# Processing Record 42 of Set 2 | marienburg
# Processing Record 43 of Set 2 | gat
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 2 | visnes
# Processing Record 48 of Set 2 | beringovskiy
# Processing Record 49 of Set 2 | ust-tsilma
# Processing Record 50 of Set 2 | thunder bay
# Processing Record 1 of Set 3 | lorengau
# Processing Record 2 of Set 3 | ixtapa
# Processing Record 3 of Set 3 | pangnirtung
# Processing Record 4 of Set 3 | tiznit
# Processing Record 5 of Set 3 | danilovka
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | turukhansk
# Processing Record 8 of Set 3 | oudtshoorn
# Processing Record 9 of Set 3 | muyezerskiy
# Processing Record 10 of Set 3 | polonnaruwa
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | vila
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | piney green
# Processing Record 16 of Set 3 | east wenatchee bench
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | hambantota
# Processing Record 19 of Set 3 | cairns
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | mount gambier
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | morgan city
# Processing Record 27 of Set 3 | marsa matruh
# Processing Record 28 of Set 3 | nizhniy odes
# Processing Record 29 of Set 3 | san lorenzo
# Processing Record 30 of Set 3 | bonavista
# Processing Record 31 of Set 3 | coihaique
# Processing Record 32 of Set 3 | mount isa
# Processing Record 33 of Set 3 | akyab
# Processing Record 34 of Set 3 | suhbaatar
# Processing Record 35 of Set 3 | cabinda
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | cabo san lucas
# Processing Record 38 of Set 3 | cambyreta
# City not found. Skipping...
# Processing Record 39 of Set 3 | luhyny
# Processing Record 40 of Set 3 | inhambane
# Processing Record 41 of Set 3 | coquimbo
# Processing Record 42 of Set 3 | armizonskoye
# Processing Record 43 of Set 3 | aswan
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | grand-santi
# Processing Record 46 of Set 3 | aksarayskiy
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | fort frances
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | biaora
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | shizunai
# Processing Record 3 of Set 4 | salalah
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | san blas
# Processing Record 8 of Set 4 | arraial do cabo
# Processing Record 9 of Set 4 | alamos
# Processing Record 10 of Set 4 | labuhan
# Processing Record 11 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | mulki
# Processing Record 16 of Set 4 | behbahan
# Processing Record 17 of Set 4 | san cristobal
# Processing Record 18 of Set 4 | baykit
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | bambanglipuro
# Processing Record 21 of Set 4 | peleduy
# Processing Record 22 of Set 4 | corinto
# Processing Record 23 of Set 4 | mirnyy
# Processing Record 24 of Set 4 | the valley
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | wuwei
# Processing Record 27 of Set 4 | mortka
# Processing Record 28 of Set 4 | japura
# Processing Record 29 of Set 4 | ukrayinka
# Processing Record 30 of Set 4 | chokurdakh
# Processing Record 31 of Set 4 | korla
# Processing Record 32 of Set 4 | luganville
# Processing Record 33 of Set 4 | ahipara
# Processing Record 34 of Set 4 | burkhala
# City not found. Skipping...
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | sikasso
# Processing Record 37 of Set 4 | tessalit
# Processing Record 38 of Set 4 | haines junction
# Processing Record 39 of Set 4 | pyay
# Processing Record 40 of Set 4 | saint-pierre
# Processing Record 41 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 4 | fort nelson
# Processing Record 43 of Set 4 | buala
# Processing Record 44 of Set 4 | surt
# Processing Record 45 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 4 | san marcos
# Processing Record 47 of Set 4 | kadoma
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | melito di porto salvo
# Processing Record 50 of Set 4 | east london
# Processing Record 1 of Set 5 | chilca
# Processing Record 2 of Set 5 | cooma
# Processing Record 3 of Set 5 | nosy varika
# Processing Record 4 of Set 5 | cortez
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | hofn
# Processing Record 7 of Set 5 | lobez
# Processing Record 8 of Set 5 | saint-denis
# Processing Record 9 of Set 5 | luchegorsk
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | asau
# Processing Record 12 of Set 5 | nanortalik
# Processing Record 13 of Set 5 | mamallapuram
# Processing Record 14 of Set 5 | caravelas
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | damara
# Processing Record 17 of Set 5 | rocha
# Processing Record 18 of Set 5 | hennenman
# Processing Record 19 of Set 5 | san patricio
# Processing Record 20 of Set 5 | cavalcante
# Processing Record 21 of Set 5 | tabuk
# Processing Record 22 of Set 5 | muisne
# Processing Record 23 of Set 5 | xam nua
# Processing Record 24 of Set 5 | dunstable
# Processing Record 25 of Set 5 | manta
# Processing Record 26 of Set 5 | santo domingo
# Processing Record 27 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 5 | anadyr
# Processing Record 29 of Set 5 | mizdah
# Processing Record 30 of Set 5 | aguimes
# Processing Record 31 of Set 5 | doaba
# Processing Record 32 of Set 5 | mahebourg
# Processing Record 33 of Set 5 | muroto
# Processing Record 34 of Set 5 | bokoro
# Processing Record 35 of Set 5 | itaituba
# Processing Record 36 of Set 5 | umm kaddadah
# Processing Record 37 of Set 5 | saint-philippe
# Processing Record 38 of Set 5 | qasigiannguit
# Processing Record 39 of Set 5 | port elizabeth
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | barrow
# Processing Record 43 of Set 5 | skovorodino
# Processing Record 44 of Set 5 | ewo
# Processing Record 45 of Set 5 | am timan
# Processing Record 46 of Set 5 | karratha
# Processing Record 47 of Set 5 | dikson
# Processing Record 48 of Set 5 | merrill
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | abu samrah
# Processing Record 1 of Set 6 | atid
# Processing Record 2 of Set 6 | valparaiso
# Processing Record 3 of Set 6 | la ronge
# Processing Record 4 of Set 6 | saskylakh
# Processing Record 5 of Set 6 | bugojno
# Processing Record 6 of Set 6 | chapleau
# Processing Record 7 of Set 6 | shache
# Processing Record 8 of Set 6 | methoni
# Processing Record 9 of Set 6 | pindiga
# Processing Record 10 of Set 6 | mama
# Processing Record 11 of Set 6 | altamira
# Processing Record 12 of Set 6 | sinop
# Processing Record 13 of Set 6 | sao felix do xingu
# Processing Record 14 of Set 6 | kodinsk
# Processing Record 15 of Set 6 | yar-sale
# Processing Record 16 of Set 6 | omsukchan
# Processing Record 17 of Set 6 | lavrentiya
# Processing Record 18 of Set 6 | nome
# Processing Record 19 of Set 6 | kieta
# Processing Record 20 of Set 6 | miles city
# Processing Record 21 of Set 6 | fort saint james
# Processing Record 22 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 24 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 6 | axim
# Processing Record 26 of Set 6 | vrangel
# Processing Record 27 of Set 6 | nuevo casas grandes
# Processing Record 28 of Set 6 | galesong
# Processing Record 29 of Set 6 | morondava
# Processing Record 30 of Set 6 | kibala
# Processing Record 31 of Set 6 | gidam
# Processing Record 32 of Set 6 | urumqi
# Processing Record 33 of Set 6 | nanyamba
# Processing Record 34 of Set 6 | rassvet
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | antofagasta
# Processing Record 37 of Set 6 | winsum
# Processing Record 38 of Set 6 | ansbach
# Processing Record 39 of Set 6 | jumla
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | nouakchott
# Processing Record 42 of Set 6 | pathein
# Processing Record 43 of Set 6 | palana
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | baruun-urt
# Processing Record 46 of Set 6 | ossora
# Processing Record 47 of Set 6 | carlagan
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | piacabucu
# Processing Record 50 of Set 6 | lushunkou
# City not found. Skipping...
# Processing Record 1 of Set 7 | rawson
# Processing Record 2 of Set 7 | san vicente
# Processing Record 3 of Set 7 | laguna
# Processing Record 4 of Set 7 | dali
# Processing Record 5 of Set 7 | laukaa
# Processing Record 6 of Set 7 | port hedland
# Processing Record 7 of Set 7 | uige
# Processing Record 8 of Set 7 | bahia honda
# Processing Record 9 of Set 7 | dasoguz
# Processing Record 10 of Set 7 | sirjan
# Processing Record 11 of Set 7 | puntarenas
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | broome
# Processing Record 14 of Set 7 | mackay
# Processing Record 15 of Set 7 | miri
# Processing Record 16 of Set 7 | ovalle
# Processing Record 17 of Set 7 | leshukonskoye
# Processing Record 18 of Set 7 | mendoza
# Processing Record 19 of Set 7 | leesburg
# Processing Record 20 of Set 7 | vostok
# Processing Record 21 of Set 7 | ilulissat
# Processing Record 22 of Set 7 | dera din panah
# City not found. Skipping...
# Processing Record 23 of Set 7 | mormugao
# Processing Record 24 of Set 7 | mitsamiouli
# Processing Record 25 of Set 7 | le pont-de-claix
# Processing Record 26 of Set 7 | pila
# Processing Record 27 of Set 7 | okoneshnikovo
# Processing Record 28 of Set 7 | mier
# Processing Record 29 of Set 7 | nyurba
# Processing Record 30 of Set 7 | okha
# Processing Record 31 of Set 7 | mandera
# Processing Record 32 of Set 7 | qaqortoq
# Processing Record 33 of Set 7 | luderitz
# Processing Record 34 of Set 7 | kamuli
# Processing Record 35 of Set 7 | sungurlu
# Processing Record 36 of Set 7 | mercedes
# Processing Record 37 of Set 7 | sobolevo
# Processing Record 38 of Set 7 | pobe
# Processing Record 39 of Set 7 | port hardy
# Processing Record 40 of Set 7 | avera
# Processing Record 41 of Set 7 | peniche
# Processing Record 42 of Set 7 | bam
# Processing Record 43 of Set 7 | tchollire
# Processing Record 44 of Set 7 | san quintin
# Processing Record 45 of Set 7 | staraya mayna
# Processing Record 46 of Set 7 | thinadhoo
# Processing Record 47 of Set 7 | suluq
# Processing Record 48 of Set 7 | izhmorskiy
# Processing Record 49 of Set 7 | praia da vitoria
# Processing Record 50 of Set 7 | kyabe
# Processing Record 1 of Set 8 | kahului
# Processing Record 2 of Set 8 | cilegon
# Processing Record 3 of Set 8 | jimeta
# Processing Record 4 of Set 8 | cuenca
# Processing Record 5 of Set 8 | aquiraz
# Processing Record 6 of Set 8 | concordia
# Processing Record 7 of Set 8 | gizo
# Processing Record 8 of Set 8 | tiarei
# Processing Record 9 of Set 8 | muskogee
# Processing Record 10 of Set 8 | ikom
# Processing Record 11 of Set 8 | fort-shevchenko
# Processing Record 12 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 8 | kathmandu
# Processing Record 14 of Set 8 | kincardine
# Processing Record 15 of Set 8 | paratinga
# Processing Record 16 of Set 8 | nishihara
# Processing Record 17 of Set 8 | carndonagh
# Processing Record 18 of Set 8 | airai
# Processing Record 19 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 8 | lisakovsk
# Processing Record 21 of Set 8 | dunn
# Processing Record 22 of Set 8 | dakar
# Processing Record 23 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 24 of Set 8 | saint joseph
# Processing Record 25 of Set 8 | sao filipe
# Processing Record 26 of Set 8 | rey bouba
# Processing Record 27 of Set 8 | muncar
# Processing Record 28 of Set 8 | nyrob
# Processing Record 29 of Set 8 | waingapu
# Processing Record 30 of Set 8 | ishigaki
# Processing Record 31 of Set 8 | dunedin
# Processing Record 32 of Set 8 | sikea
# City not found. Skipping...
# Processing Record 33 of Set 8 | lewistown
# Processing Record 34 of Set 8 | saint george
# Processing Record 35 of Set 8 | steamboat springs
# Processing Record 36 of Set 8 | rundu
# Processing Record 37 of Set 8 | arlit
# Processing Record 38 of Set 8 | uyemskiy
# Processing Record 39 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 8 | livingston
# Processing Record 41 of Set 8 | suntar
# Processing Record 42 of Set 8 | biak
# Processing Record 43 of Set 8 | cockburn town
# Processing Record 44 of Set 8 | makakilo city
# Processing Record 45 of Set 8 | cherskiy
# Processing Record 46 of Set 8 | ler
# Processing Record 47 of Set 8 | chapais
# Processing Record 48 of Set 8 | svetlogorsk
# Processing Record 49 of Set 8 | zheleznodorozhnyy
# Processing Record 50 of Set 8 | dalgopol
# Processing Record 1 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 9 | itarema
# Processing Record 3 of Set 9 | boa vista
# Processing Record 4 of Set 9 | sao joao evangelista
# Processing Record 5 of Set 9 | acapulco
# Processing Record 6 of Set 9 | kuragino
# Processing Record 7 of Set 9 | chernyshevskiy
# Processing Record 8 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 9 of Set 9 | zhigansk
# Processing Record 10 of Set 9 | serenje
# Processing Record 11 of Set 9 | machacamarca
# Processing Record 12 of Set 9 | xinzhi
# Processing Record 13 of Set 9 | calabozo
# Processing Record 14 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 9 | torbay
# Processing Record 16 of Set 9 | honiara
# Processing Record 17 of Set 9 | seoul
# Processing Record 18 of Set 9 | kafanchan
# Processing Record 19 of Set 9 | saint-georges
# Processing Record 20 of Set 9 | jiancheng
# Processing Record 21 of Set 9 | makhinjauri
# Processing Record 22 of Set 9 | fukue
# Processing Record 23 of Set 9 | hailar
# Processing Record 24 of Set 9 | mehtar lam
# Processing Record 25 of Set 9 | benguela
# Processing Record 26 of Set 9 | xai-xai
# Processing Record 27 of Set 9 | cabra
# Processing Record 28 of Set 9 | katsuura
# Processing Record 29 of Set 9 | auxerre
# Processing Record 30 of Set 9 | champagnole
# Processing Record 31 of Set 9 | codrington
# Processing Record 32 of Set 9 | banda aceh
# Processing Record 33 of Set 9 | malartic
# Processing Record 34 of Set 9 | rupert
# Processing Record 35 of Set 9 | namibe
# Processing Record 36 of Set 9 | xiashi
# Processing Record 37 of Set 9 | davenda
# Processing Record 38 of Set 9 | boca do acre
# Processing Record 39 of Set 9 | kijang
# Processing Record 40 of Set 9 | katete
# Processing Record 41 of Set 9 | lethem
# Processing Record 42 of Set 9 | margate
# Processing Record 43 of Set 9 | pavilosta
# Processing Record 44 of Set 9 | havre-saint-pierre
# Processing Record 45 of Set 9 | sabha
# Processing Record 46 of Set 9 | pontianak
# Processing Record 47 of Set 9 | sarlat-la-caneda
# Processing Record 48 of Set 9 | ca mau
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | minyar
# Processing Record 1 of Set 10 | huarmey
# Processing Record 2 of Set 10 | lensk
# Processing Record 3 of Set 10 | port lincoln
# Processing Record 4 of Set 10 | erenhot
# Processing Record 5 of Set 10 | dongsheng
# Processing Record 6 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 10 | tubli
# Processing Record 8 of Set 10 | mwandiga
# Processing Record 9 of Set 10 | dingle
# Processing Record 10 of Set 10 | searcy
# Processing Record 11 of Set 10 | poronaysk
# Processing Record 12 of Set 10 | aban
# Processing Record 13 of Set 10 | cape coast
# Processing Record 14 of Set 10 | tilichiki
# Processing Record 15 of Set 10 | itirapina
# Processing Record 16 of Set 10 | newcastleton
# Processing Record 17 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 10 | araouane
# Processing Record 19 of Set 10 | ures
# Processing Record 20 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 10 | yekaterinoslavka
# Processing Record 23 of Set 10 | tselinnoye
# Processing Record 24 of Set 10 | bengkulu
# Processing Record 25 of Set 10 | abay
# Processing Record 26 of Set 10 | mahibadhoo
# Processing Record 27 of Set 10 | abeche
# Processing Record 28 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 29 of Set 10 | san luis
# Processing Record 30 of Set 10 | kirkenes
# Processing Record 31 of Set 10 | sandovo
# Processing Record 32 of Set 10 | whitehorse
# Processing Record 33 of Set 10 | mecca
# Processing Record 34 of Set 10 | stokmarknes
# Processing Record 35 of Set 10 | neuquen
# Processing Record 36 of Set 10 | rajur
# Processing Record 37 of Set 10 | lakota
# Processing Record 38 of Set 10 | carutapera
# Processing Record 39 of Set 10 | cordoba
# Processing Record 40 of Set 10 | ayan
# Processing Record 41 of Set 10 | gemena
# Processing Record 42 of Set 10 | bandarbeyla
# Processing Record 43 of Set 10 | tommot
# Processing Record 44 of Set 10 | oneonta
# Processing Record 45 of Set 10 | pointe-noire
# Processing Record 46 of Set 10 | meadow lake
# Processing Record 47 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 10 | yaan
# Processing Record 49 of Set 10 | binidayan
# Processing Record 50 of Set 10 | navahrudak
# Processing Record 1 of Set 11 | sanandrei
# Processing Record 2 of Set 11 | sola
# Processing Record 3 of Set 11 | sungai siput utara
# City not found. Skipping...
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | jayanca
# Processing Record 6 of Set 11 | riyadh
# Processing Record 7 of Set 11 | tazovskiy
# Processing Record 8 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 11 | byron bay
# Processing Record 10 of Set 11 | cap malheureux
# Processing Record 11 of Set 11 | pierre
# Processing Record 12 of Set 11 | argostolion
# Processing Record 13 of Set 11 | santa marta de tormes
# Processing Record 14 of Set 11 | noyabrsk
# Processing Record 15 of Set 11 | cuxhaven
# Processing Record 16 of Set 11 | vardo
# Processing Record 17 of Set 11 | xinqing
# Processing Record 18 of Set 11 | sfantu gheorghe
# Processing Record 19 of Set 11 | paamiut
# Processing Record 20 of Set 11 | tecoanapa
# Processing Record 21 of Set 11 | casper
# Processing Record 22 of Set 11 | te anau
# Processing Record 23 of Set 11 | atikokan
# Processing Record 24 of Set 11 | madang
# Processing Record 25 of Set 11 | richards bay
# Processing Record 26 of Set 11 | poum
# Processing Record 27 of Set 11 | rioblanco
# Processing Record 28 of Set 11 | yining
# Processing Record 29 of Set 11 | itaguai
# Processing Record 30 of Set 11 | buta
# Processing Record 31 of Set 11 | monrovia
# Processing Record 32 of Set 11 | caninde de sao francisco
# Processing Record 33 of Set 11 | ondangwa
# Processing Record 34 of Set 11 | eureka
# Processing Record 35 of Set 11 | belyy yar
# Processing Record 36 of Set 11 | aitape
# Processing Record 37 of Set 11 | dano
# Processing Record 38 of Set 11 | sioux lookout
# Processing Record 39 of Set 11 | sivas
# Processing Record 40 of Set 11 | tairua
# Processing Record 41 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 42 of Set 11 | abashiri
# Processing Record 43 of Set 11 | tooele
# Processing Record 44 of Set 11 | prochnookopskaya
# Processing Record 45 of Set 11 | manono
# Processing Record 46 of Set 11 | templin
# Processing Record 47 of Set 11 | port-gentil
# Processing Record 48 of Set 11 | padang
# Processing Record 49 of Set 11 | kasamwa
# Processing Record 50 of Set 11 | balabac
# Processing Record 1 of Set 12 | kalmunai
# Processing Record 2 of Set 12 | turayf
# Processing Record 3 of Set 12 | poli
# Processing Record 4 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 6 of Set 12 | bolivar
# Processing Record 7 of Set 12 | marzuq
# Processing Record 8 of Set 12 | xiantao
# Processing Record 9 of Set 12 | liverpool
# Processing Record 10 of Set 12 | oksfjord
# Processing Record 11 of Set 12 | urengoy
# Processing Record 12 of Set 12 | kavaratti
# Processing Record 13 of Set 12 | lindi
# Processing Record 14 of Set 12 | turbat
# Processing Record 15 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 12 | linxia
# Processing Record 17 of Set 12 | chenghai
# Processing Record 18 of Set 12 | moerai
# Processing Record 19 of Set 12 | barstow
# Processing Record 20 of Set 12 | zhaotong
# Processing Record 21 of Set 12 | hospet
# Processing Record 22 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 23 of Set 12 | aykhal
# Processing Record 24 of Set 12 | nador
# Processing Record 25 of Set 12 | yerbogachen
# Processing Record 26 of Set 12 | takoradi
# Processing Record 27 of Set 12 | bombay
# Processing Record 28 of Set 12 | eregli
# Processing Record 29 of Set 12 | russell
# Processing Record 30 of Set 12 | blagoyevo
# Processing Record 31 of Set 12 | taksimo
# Processing Record 32 of Set 12 | yulara
# Processing Record 33 of Set 12 | natal
# Processing Record 34 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 12 | birnin kebbi
# Processing Record 36 of Set 12 | nouadhibou
# Processing Record 37 of Set 12 | puerto escondido
# Processing Record 38 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 12 | sur
# Processing Record 40 of Set 12 | bathsheba
# Processing Record 41 of Set 12 | knyaginino
# Processing Record 42 of Set 12 | hun
# Processing Record 43 of Set 12 | leningradskiy
# Processing Record 44 of Set 12 | beira
# Processing Record 45 of Set 12 | san marcos de colon
# Processing Record 46 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 12 | dublin
# Processing Record 48 of Set 12 | iquitos
# Processing Record 49 of Set 12 | cerrito
# Processing Record 50 of Set 12 | gorontalo
# Processing Record 1 of Set 13 | vilhena
# Processing Record 2 of Set 13 | pevek
# Processing Record 3 of Set 13 | khasan
# Processing Record 4 of Set 13 | luau
# Processing Record 5 of Set 13 | phan thiet
# Processing Record 6 of Set 13 | kloulklubed
# Processing Record 7 of Set 13 | santa rosalia
# Processing Record 8 of Set 13 | rutland
# Processing Record 9 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 13 | high prairie
# Processing Record 11 of Set 13 | gimbi
# Processing Record 12 of Set 13 | zambezi
# Processing Record 13 of Set 13 | poya
# Processing Record 14 of Set 13 | ingham
# Processing Record 15 of Set 13 | wawina
# Processing Record 16 of Set 13 | lebu
# Processing Record 17 of Set 13 | tabou
# Processing Record 18 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 13 | betsiamites
# Processing Record 20 of Set 13 | kenora
# Processing Record 21 of Set 13 | alofi
# Processing Record 22 of Set 13 | gondanglegi
# Processing Record 23 of Set 13 | doha
# Processing Record 24 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 25 of Set 13 | mujiayingzi
# Processing Record 26 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 13 | biltine
# Processing Record 28 of Set 13 | slave lake
# Processing Record 29 of Set 13 | noumea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Retrieve the following information from the API and add to Data Frame
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0   Port Alfred      ZA  2020-04-19 15:54:32 -33.59   26.89     81.54
# 1     Grindavik      IS  2020-04-19 15:49:22  63.84  -22.43     46.99
# 2       Shimoda      JP  2020-04-19 15:54:43  34.67  138.95     55.00
# 3       Ushuaia      AR  2020-04-19 15:51:46 -54.80  -68.30     44.60
# 4         Kapaa      US  2020-04-19 15:53:45  22.08 -159.32     69.80
# 5          Chuy      UY  2020-04-19 15:53:51 -33.70  -53.46     71.15
# 6  Puerto Ayora      EC  2020-04-19 15:46:57  -0.74  -90.35     84.00
# 7      Khatanga      RU  2020-04-19 15:54:55  71.97  102.50     18.73
# 8        Juruti      BR  2020-04-19 15:55:47  -2.15  -56.09     74.66
# 9    Kaitangata      NZ  2020-04-19 15:49:00 -46.28  169.85     48.99
#
#    Humidity  Cloudiness  Wind Speed              description  \
# 0        52          39       17.45         scattered clouds
# 1       100          90       23.04  light intensity drizzle
# 2        84         100        1.99          overcast clouds
# 3        75          75        1.10            broken clouds
# 4        83          90        5.82          overcast clouds
# 5        67           0        7.92                clear sky
# 6        83          40       13.87         scattered clouds
# 7        94          43        4.99         scattered clouds
# 8        96         100        1.81            moderate rain
# 9        54          54        8.01            broken clouds
#
#    Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 0                      0.00                       0.0
# 1                      0.00                       0.0
# 2                      0.00                       0.0
# 3                      0.00                       0.0
# 4                      0.00                       0.0
# 5                      0.00                       0.0
# 6                      0.00                       0.0
# 7                      0.00                       0.0
# 8                     10.67                       0.0
# 9                      0.00                       0.0

# %%
#Save the new DataFrame as a CSV - WeatherPy_challenge.csv
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#How Many Cities have rainfall or Snow
rain_snow_df = city_data_df.loc[(city_data_df["Rain Inches (last 3 hrs)"] > 0.0) | (city_data_df["Snow Inches (last 3 hrs)"] > 0.0)]
print(f"There are",rain_snow_df["City"].count(),"cities with snow or rain")
# Out:
# There are 109 cities with snow or rain
